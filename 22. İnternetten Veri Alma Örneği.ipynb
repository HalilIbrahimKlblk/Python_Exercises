# %%
import requests
from bs4 import BeautifulSoup

url = "http://www.imdb.com/chart/top"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}
response = requests.get(url, headers=headers)
html_iceriği=response.content
soup=BeautifulSoup(html_iceriği,"html.parser")

başlıklar = soup.find_all("h3",{"class":"ipc-title__text"})
puanlar = soup.find_all("div",{"class":"sc-e3e7b191-0 iKUUVe sc-b85248f1-2 wTpct cli-ratings-container"})

silinecek_indeksler=[0,261,260,259,258,257,256,255,254,253,252,251,250]
for i in silinecek_indeksler:
    del başlıklar[i]

for başlıklar,puanlar in zip(başlıklar,puanlar):
    print(başlıklar.text,"  ", "Puan:", puanlar.text)
    print("-"*77)
# Out:
# 1. The Shawshank Redemption    Puan: 9.3 (2.8M)Rate
# -----------------------------------------------------------------------------
# 2. The Godfather    Puan: 9.2 (1.9M)Rate
# -----------------------------------------------------------------------------
# 3. The Dark Knight    Puan: 9.0 (2.8M)Rate
# -----------------------------------------------------------------------------
# 4. The Godfather Part II    Puan: 9.0 (1.3M)Rate
# -----------------------------------------------------------------------------
# 5. 12 Angry Men    Puan: 9.0 (831K)Rate
# -----------------------------------------------------------------------------
# 6. Schindler's List    Puan: 9.0 (1.4M)Rate
# -----------------------------------------------------------------------------
# 7. The Lord of the Rings: The Return of the King    Puan: 9.0 (1.9M)Rate
# -----------------------------------------------------------------------------
# 8. Pulp Fiction    Puan: 8.9 (2.1M)Rate
# ...
